# %%
x = 10
y = 0
print(x/y)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 x = 10
#       2 y = 0
# ----> 3 print(x/y)
#
# ZeroDivisionError: division by zero

# %%
try:
    x = 10
    y = 0
    print(x/y)
except ZeroDivisionError:
    print("divisao por zero")
# Out:
# divisao por zero

# %%
try:
    x = 10
    y = 0
    print(x/y)
except Exception as e:
    print(f"erro {e}")
# Out:
# erro division by zero

# %%
try:
    x = 10
    y = 0
    print(x/y)
except ZeroDivisionError:
    print("divisao por zero")
finally:
    print("encerrando")
# Out:
# divisao por zero
# encerrando

# %%
from urllib.request import urlopen
url = "https://patents.google.com/patent/US5000000A/en?oq=US5000000"
response = urlopen(url)
html = response.read().decode("utf-8")
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>US5000000A - Ethanol production by Escherichia coli strains co-expressing Zymomonas PDC and ADH genes
#         - Google Patents</title>
#
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <meta charset="UTF-8">
#     <meta name="referrer" content="origin-when-crossorigin">
#     <link rel="canonical" href="https://patents.google.com/patent/US5000000A/en">
#     <meta name="description" content="
#      A novel operon and plasmids comprising genes which code for the alcohol dehydrogenase and pyruvate decarboxylase activities of Zymomonas mobilis are described. Also disclosed are methods for increasing the growth of microorganisms or eukaryotic cells and methods for reducing the accumulation of undesirable metabolic products in the growth medium of microorganisms or cells.
#
#    ">
#     <meta name="DC.type" content="patent">
#     <meta name="DC.title" content="Ethanol production by Escherichia coli strains co-expressing Zymomonas PDC and ADH genes
#        ">
#     <meta name="DC.date" content="1989-05-15" scheme="dateSubmitted">
#     <meta name="DC.description" content="
#      A novel operon and plasmids comprising genes which code for the alcohol dehydrogenase and pyruvate decarboxylase activities of Zymomonas mobilis are described. Also disclosed are methods for increasing the growth of microorganisms or eukaryotic cells and methods for reducing the accumulation of undesirable metabolic products in the growth medium of microorganisms or cells.
#
#    ">
#     <meta name="citation_patent_application_number" content="US:07/352,062">
#     <meta name="citation_pdf_url" content="https://patentimages.storage.googleapis.com/38/b8/e9/d5ead969ab4647/US5000000.pdf">
#     <meta name="citation_patent_number" content="US:5000000">
#     <meta name="DC.date" content="1991-03-19" scheme="issue">
#     <meta name="DC.contributor" content="Lonnie O. Ingram" scheme="inventor">
#     <meta name="DC.contributor" content="Tyrrell Conway" scheme="inventor">
#     <meta name="DC.contributor" content="Flavio Alterthum" scheme="inventor">
#     <meta name="DC.contributor" content="University of Florida" scheme="assignee">
#     <meta name="citation_reference" content="Brau, B. and H. Sahm (1986) &#34;Cloning and Expression of the Structural Gene for Pyruvate Decarboxylase of Zymomonas mobilis in Escherichia coli,&#34; Arch. Microbiol. 144:296-301." scheme="references">
#     <meta name="citation_reference" content="Brau, B. and H. Sahm (1986) Cloning and Expression of the Structural Gene for Pyruvate Decarboxylase of Zymomonas mobilis in Escherichia coli, Arch. Microbiol. 144:296 301." scheme="references">
#     <meta name="citation_reference" content="Bringer Meyer, S., K. L. Schimz, and H. Sahm (1986) Pyruvate Decarboxylase from Zymomonas mobilis. Isolation and Partial Characterization, Arch. Microbiol. 146:105 110." scheme="references">
#     <meta name="citation_reference" content="Bringer-Meyer, S., K.-L. Schimz, and H. Sahm (1986) &#34;Pyruvate Decarboxylase from Zymomonas mobilis. Isolation and Partial Characterization,&#34; Arch. Microbiol. 146:105-110." scheme="references">
#     <meta name="citation_reference" content="Conway, T., G. W. Sewell, Y. A. Osman and L. O. Ingram (1987) &#34;Cloning and Sequencing of the Alcohol Dehydrogenase II Gene from Zymomonas mobilis,&#34; J. Bacteriol. 169:2591-2597." scheme="references">
#     <meta name="citation_reference" content="Conway, T., G. W. Sewell, Y. A. Osman and L. O. Ingram (1987) Cloning and Sequencing of the Alcohol Dehydrogenase II Gene from Zymomonas mobilis, J. Bacteriol. 169:2591 2597." scheme="references">
#     <meta name="citation_reference" content="Conway, T., Y. A. Osman, J. I. Konnan, E. M. Hoffmann, and L. O. Ingram (1987) &#34;Promoter and Nucleotide Sequences of the Zymomonas mobilis Pyruvate Decarboxylase,&#34; J. Bacteriol. 169:949-954." scheme="references">
#     <meta name="citation_reference" content="Conway, T., Y. A. Osman, J. I. Konnan, E. M. Hoffmann, and L. O. Ingram (1987) Promoter and Nucleotide Sequences of the Zymomonas mobilis Pyruvate Decarboxylase, J. Bacteriol. 169:949 954." scheme="references">
#     <meta name="citation_reference" content="Fried, V. A., A. Novick (1973) &#34;Organic Solvents as Probes for the Structure and Function of the Bacterial Membrane: Effects of Ethanol on the Wild Type and an Ethanol-Resistant Mutant of Escherichia coli K-12,&#34; J. Bacteriol. 114(1):239-248." scheme="references">
#     <meta name="citation_reference" content="Fried, V. A., A. Novick (1973) Organic Solvents as Probes for the Structure and Function of the Bacterial Membrane: Effects of Ethanol on the Wild Type and an Ethanol Resistant Mutant of Escherichia coli K 12, J. Bacteriol. 114(1):239 248." scheme="references">
#     <meta name="citation_reference" content="Ingram, L. O. (1976) &#34;Adaptation of Membrane Lipids to Alcohols,&#34; J. Bacteriol. 125(2):670-678." scheme="references">
#     <meta name="citation_reference" content="Ingram, L. O. (1976) Adaptation of Membrane Lipids to Alcohols, J. Bacteriol. 125(2):670 678." scheme="references">
#     <meta name="citation_reference" content="Ingram, L. O. and T. Conway (1988) &#34;Expression of Different Levels of Ethanologenic Enzymes from Zymomonas mobilis in Recombinant Strains of Escherichia coli,&#34; Appl. Environ. Microbiol. 54:397-404." scheme="references">
#     <meta name="citation_reference" content="Ingram, L. O. and T. Conway (1988) Expression of Different Levels of Ethanologenic Enzymes from Zymomonas mobilis in Recombinant Strains of Escherichia coli, Appl. Environ. Microbiol. 54:397 404." scheme="references">
#     <meta name="citation_reference" content="Ingram, L. O., N. S. Vreeland (1980) &#34;Differential Effects of Ethanol and Hexanol on the Escherichia coli Cell Envelope,&#34; J. Bacteriol. 144(2):481-488." scheme="references">
#     <meta name="citation_reference" content="Ingram, L. O., N. S. Vreeland (1980) Differential Effects of Ethanol and Hexanol on the Escherichia coli Cell Envelope, J. Bacteriol. 144(2):481 488." scheme="references">
#     <meta name="citation_reference" content="Ingram, L. O., T. Conway, D. P. Clark, G. W. Sewell, and J. F. Preston (1987) &#34;Genetic Engineering of Ethanol Production in Escherichia coli,&#34; Appl. Environ. Microbiol. 53:2420-2425." scheme="references">
#     <meta name="citation_reference" content="Ingram, L. O., T. Conway, D. P. Clark, G. W. Sewell, and J. F. Preston (1987) Genetic Engineering of Ethanol Production in Escherichia coli, Appl. Environ. Microbiol. 53:2420 2425." scheme="references">
#     <meta name="citation_reference" content="Ingram, L. O., T. M. Buttke (1984) &#34;Effects of Alcohols on Micro-Organisms,&#34; in Advances in Microbial Pathology, vol. 25, Academic Press, London, pp. 254-295." scheme="references">
#     <meta name="citation_reference" content="Ingram, L. O., T. M. Buttke (1984) Effects of Alcohols on Micro Organisms, in Advances in Microbial Pathology, vol. 25, Academic Press, London, pp. 254 295." scheme="references">
#     <meta name="citation_reference" content="Neale, A. D., R. K. Scopes, R. E. H. Wettenhall and N. J. Hoogenraad (1987) &#34;Nucleotide Sequence of the Pyruvate Decarboxylase Gene from Zymomonas mobilis,&#34; Nucleic Acids Res. 15:1753-1761." scheme="references">
#     <meta name="citation_reference" content="Neale, A. D., R. K. Scopes, R. E. H. Wettenhall and N. J. Hoogenraad (1987) Nucleotide Sequence of the Pyruvate Decarboxylase Gene from Zymomonas mobilis, Nucleic Acids Res. 15:1753 1761." scheme="references">
#     <meta name="citation_reference" content="Tolan, J. S. and R. K. Finn (1987) &#34;Fermentation of D-Xylose and L-Arabinos to Ethanol by Erwinia chrysanthemi,&#34; Appl. Environ. Microbiol. 53:2033-2038." scheme="references">
#     <meta name="citation_reference" content="Tolan, J. S. and R. K. Finn (1987) &#34;Fermentation of D-Xylose to Ethanol by Genetically Modified Klebsiella planticola,&#34; Appl. Environ. Microbiol. 53:2039-2044." scheme="references">
#     <meta name="citation_reference" content="Tolan, J. S. and R. K. Finn (1987) Fermentation of D Xylose and L Arabinos to Ethanol by Erwinia chrysanthemi, Appl. Environ. Microbiol. 53:2033 2038." scheme="references">
#     <meta name="citation_reference" content="Tolan, J. S. and R. K. Finn (1987) Fermentation of D Xylose to Ethanol by Genetically Modified Klebsiella planticola, Appl. Environ. Microbiol. 53:2039 2044." scheme="references">
#     <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Roboto:400,400italic,500,500italic,700">
#     <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Product+Sans">
#     <link rel="stylesheet" href="https://fonts.googleapis.com/css2?family=Google+Sans:wght@400;500;700">
#
#     <style>
#
#       #gb { top: 15px; left: auto; right: 0; width: auto; min-width: 135px !important; }
#       body { transition: none; }
#     </style>
#     <script></script>
#
#     <script>
#       window.version = 'patent-search.search_20250410_RC00';
#
#       function sendFeedback() {
#         userfeedback.api.startFeedback({
#           'productId': '713680',
#           'bucket': 'patent-search-web',
#           'productVersion': window.version,
#         });
#       }
#
#       window.experiments = {};
#       window.experiments.patentCountries = "ae,ag,al,am,ao,ap,ar,at,au,aw,az,ba,bb,bd,be,bf,bg,bh,bj,bn,bo,br,bw,bx,by,bz,ca,cf,cg,ch,ci,cl,cm,cn,co,cr,cs,cu,cy,cz,dd,de,dj,dk,dm,do,dz,ea,ec,ee,eg,em,ep,es,fi,fr,ga,gb,gc,gd,ge,gh,gm,gn,gq,gr,gt,gw,hk,hn,hr,hu,ib,id,ie,il,in,ir,is,it,jo,jp,ke,kg,kh,km,kn,kp,kr,kw,kz,la,lc,li,lk,lr,ls,lt,lu,lv,ly,ma,mc,md,me,mg,mk,ml,mn,mo,mr,mt,mw,mx,my,mz,na,ne,ng,ni,nl,no,nz,oa,om,pa,pe,pg,ph,pl,pt,py,qa,ro,rs,ru,rw,sa,sc,sd,se,sg,si,sk,sl,sm,sn,st,su,sv,sy,sz,td,tg,th,tj,tm,tn,tr,tt,tw,tz,ua,ug,us,uy,uz,vc,ve,vn,wo,yu,za,zm,zw";
#
#
#       window.experiments.keywordWizard = true;
#
#
#
#       window.experiments.definitions = true;
#       window.experiments.plogs = true;
#
#       window.Polymer = {
#         dom: 'shady',
#         lazyRegister: true,
#       };
#     </script>
#
#     <script src="//www.gstatic.com/patent-search/frontend/patent-search.search_20250410_RC00/scs/compiled_dir/webcomponentsjs/webcomponents-lite.min.js"></script>
#     <link rel="import" href="//www.gstatic.com/patent-search/frontend/patent-search.search_20250410_RC00/scs/compiled_dir/search-app-vulcanized.html">
#   </head>
#   <body unresolved>
#
#
#     <script></script>
#     <script src="//www.gstatic.com/patent-search/frontend/patent-search.search_20250410_RC00/scs/compiled_dir/search-app-vulcanized.js"></script>
#     <search-app>
#
#
#
#       <article class="result" itemscope itemtype="http://schema.org/ScholarlyArticle">
#   <h1 itemprop="pageTitle">US5000000A - Ethanol production by Escherichia coli strains co-expressing Zymomonas PDC and ADH genes
#         - Google Patents</h1>
#   <span itemprop="title">Ethanol production by Escherichia coli strains co-expressing Zymomonas PDC and ADH genes
#        </span>
#
#   <meta itemprop="type" content="patent">
#   <a href="https://patentimages.storage.googleapis.com/38/b8/e9/d5ead969ab4647/US5000000.pdf" itemprop="pdfLink">Download PDF</a>
#   <h2>Info</h2>
#
#   <dl>
#     <dt>Publication number</dt>
#     <dd itemprop="publicationNumber">US5000000A</dd>
#     <meta itemprop="numberWithoutCodes" content="5000000">
#     <meta itemprop="kindCode" content="A">
#     <meta itemprop="publicationDescription" content="Patent">
#     <span>US5000000A</span>
#     <span>US07/352,062</span>
#     <span>US35206289A</span>
#     <span>US5000000A</span>
#     <span>US 5000000 A</span>
#     <span>US5000000 A</span>
#     <span>US 5000000A</span>
#     <span>  </span>
#     <span> </span>
#     <span> </span>
#     <span>US 35206289 A</span>
#     <span>US35206289 A</span>
#     <span>US 35206289A</span>
#     <span>US 5000000 A</span>
#     <span>US5000000 A</span>
#     <span>US 5000000A</span>
#
#     <dt>Authority</dt>
#     <dd itemprop="countryCode">US</dd>
#     <dd itemprop="countryName">United States</dd>
#
#     <dt>Prior art keywords</dt>
#     <dd itemprop="priorArtKeywords" repeat>ethanol</dd>
#     <dd itemprop="priorArtKeywords" repeat>atcc</dd>
#     <dd itemprop="priorArtKeywords" repeat>ploi308</dd>
#     <dd itemprop="priorArtKeywords" repeat>growth</dd>
#     <dd itemprop="priorArtKeywords" repeat>strains</dd>
#
#     <dt>Prior art date</dt>
#     <dd><time itemprop="priorArtDate" datetime="1988-08-31">1988-08-31</time></dd>
#
#     <dt>Legal status (The legal status is an assumption and is not a legal conclusion. Google has not performed a legal analysis and makes no representation as to the accuracy of the status listed.)</dt>
#     <dd itemprop="legalStatusIfi" itemscope>
#       <span itemprop="status">Expired - Lifetime</span>
#     </dd>
#   </dl>
#
#   <dt>Application number</dt>
#   <dd itemprop="applicationNumber">US07/352,062</dd>
#
#
#
#
#
#   <dt>Inventor</dt>
#   <dd itemprop="inventor" repeat>Lonnie O. Ingram</dd>
#   <dd itemprop="inventor" repeat>Tyrrell Conway</dd>
#   <dd itemprop="inventor" repeat>Flavio Alterthum</dd>
#
#   <dt>Current Assignee (The listed assignees may be inaccurate. Google has not performed a legal analysis and makes no representation or warranty as to the accuracy of the list.)</dt>
#   <dd itemprop="assigneeCurrent" repeat>
#     University of Florida Research Foundation Inc
#   </dd>
#
#   <dt>Original Assignee</dt>
#   <dd itemprop="assigneeOriginal" repeat>University of Florida</dd>
#
#   <dt>Priority date (The priority date is an assumption and is not a legal conclusion. Google has not performed a legal analysis and makes no representation as to the accuracy of the date listed.)</dt>
#   <dd><time itemprop="priorityDate" datetime="1988-08-31">1988-08-31</time></dd>
#
#   <dt>Filing date</dt>
#   <dd><time itemprop="filingDate" datetime="1989-05-15">1989-05-15</time></dd>
#
#   <dt>Publication date</dt>
#   <dd><time itemprop="publicationDate" datetime="1991-03-19">1991-03-19</time></dd>
#
#
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1989-05-15">1989-05-15</time>
#     <span itemprop="title">Application filed by University of Florida</span>
#     <span itemprop="type">filed</span>
#     <span itemprop="critical" content="true" bool>Critical</span>
#
#
#
#     <span itemprop="assigneeSearch">University of Florida</span>
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1989-05-15">1989-05-15</time>
#     <span itemprop="title">Priority to US07/352,062</span>
#     <span itemprop="type">priority</span>
#     <span itemprop="critical" content="true" bool>Critical</span>
#
#
#     <span itemprop="documentId">patent/US5000000A/en</span>
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1989-05-15">1989-05-15</time>
#     <span itemprop="title">Assigned to UNIVERSITY OF FLORIDA, THE</span>
#     <span itemprop="type">reassignment</span>
#
#
#
#
#     <span itemprop="assigneeSearch">UNIVERSITY OF FLORIDA, THE</span>
#     <span itemprop="description" repeat>ASSIGNMENT OF ASSIGNORS INTEREST.</span>
#     <span itemprop="description" repeat>Assignors: ALTERTHUM, FLAVIO, INGRAM, LONNIE O.</span>
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1989-06-01">1989-06-01</time>
#     <span itemprop="title">Assigned to UNIVERSITY OF FLORIDA, THE</span>
#     <span itemprop="type">reassignment</span>
#
#
#
#
#     <span itemprop="assigneeSearch">UNIVERSITY OF FLORIDA, THE</span>
#     <span itemprop="description" repeat>ASSIGNMENT OF ASSIGNORS INTEREST.</span>
#     <span itemprop="description" repeat>Assignors: CONWAY, TYRRELL</span>
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1989-08-29">1989-08-29</time>
#     <span itemprop="title">Priority to KR1019900700901A</span>
#     <span itemprop="type">priority</span>
#
#
#
#     <span itemprop="documentId">patent/KR900702042A/en</span>
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1989-08-29">1989-08-29</time>
#     <span itemprop="title">Priority to JP1509287A</span>
#     <span itemprop="type">priority</span>
#
#
#
#     <span itemprop="documentId">patent/JPH05502366A/en</span>
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1989-08-29">1989-08-29</time>
#     <span itemprop="title">Priority to EP89909966A</span>
#     <span itemprop="type">priority</span>
#
#
#
#     <span itemprop="documentId">patent/EP0431047A1/en</span>
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1989-08-29">1989-08-29</time>
#     <span itemprop="title">Priority to HU895771A</span>
#     <span itemprop="type">priority</span>
#
#
#
#     <span itemprop="documentId">patent/HUT60328A/en</span>
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1989-08-29">1989-08-29</time>
#     <span itemprop="title">Priority to PCT/US1989/003753</span>
#     <span itemprop="type">priority</span>
#
#
#
#     <span itemprop="documentId">patent/WO1990002193A1/en</span>
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1989-08-30">1989-08-30</time>
#     <span itemprop="title">Priority to AR89314798A</span>
#     <span itemprop="type">priority</span>
#
#
#
#     <span itemprop="documentId">patent/AR242634A1/en</span>
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1989-08-30">1989-08-30</time>
#     <span itemprop="title">Priority to CA000609829A</span>
#     <span itemprop="type">priority</span>
#
#
#
#     <span itemprop="documentId">patent/CA1335430C/en</span>
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1991-03-19">1991-03-19</time>
#     <span itemprop="title">Publication of US5000000A</span>
#     <span itemprop="type">publication</span>
#     <span itemprop="critical" content="true" bool>Critical</span>
#
#
#     <span itemprop="documentId">patent/US5000000A/en</span>
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1991-03-19">1991-03-19</time>
#     <span itemprop="title">Application granted</span>
#     <span itemprop="type">granted</span>
#     <span itemprop="critical" content="true" bool>Critical</span>
#
#
#
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1992-03-06">1992-03-06</time>
#     <span itemprop="title">Priority to US07/846,344</span>
#     <span itemprop="type">priority</span>
#
#
#
#     <span itemprop="documentId">patent/US5424202A/en</span>
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1992-09-17">1992-09-17</time>
#     <span itemprop="title">Priority to US07/946,290</span>
#     <span itemprop="type">priority</span>
#
#
#
#     <span itemprop="documentId">patent/US5487989A/en</span>
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1993-12-09">1993-12-09</time>
#     <span itemprop="title">Assigned to UNIVERSITY OF FLORIDA RESEARCH FOUNDATION, INCORPORATED</span>
#     <span itemprop="type">reassignment</span>
#
#
#
#
#     <span itemprop="assigneeSearch">UNIVERSITY OF FLORIDA RESEARCH FOUNDATION, INCORPORATED</span>
#     <span itemprop="description" repeat>ASSIGNMENT OF ASSIGNORS INTEREST (SEE DOCUMENT FOR DETAILS).</span>
#     <span itemprop="description" repeat>Assignors: UNIVERSITY OF FLORIDA</span>
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1994-03-30">1994-03-30</time>
#     <span itemprop="title">Priority to US08/220,072</span>
#     <span itemprop="type">priority</span>
#
#
#
#     <span itemprop="documentId">patent/US5482846A/en</span>
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1994-12-27">1994-12-27</time>
#     <span itemprop="title">Priority to US08/363,868</span>
#     <span itemprop="type">priority</span>
#
#
#
#     <span itemprop="documentId">patent/US5821093A/en</span>
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1995-06-07">1995-06-07</time>
#     <span itemprop="title">Priority to US08/475,925</span>
#     <span itemprop="type">priority</span>
#
#
#
#     <span itemprop="documentId">patent/US5916787A/en</span>
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="1998-08-14">1998-08-14</time>
#     <span itemprop="title">Priority to US09/134,403</span>
#     <span itemprop="type">priority</span>
#
#
#
#     <span itemprop="documentId">patent/US6107093A/en</span>
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="2000-07-21">2000-07-21</time>
#     <span itemprop="title">Priority to US09/620,060</span>
#     <span itemprop="type">priority</span>
#
#
#
#     <span itemprop="documentId">patent/US7192772B1/en</span>
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="2001-11-30">2001-11-30</time>
#     <span itemprop="title">Priority to US10/001,218</span>
#     <span itemprop="type">priority</span>
#
#
#
#     <span itemprop="documentId">patent/US6849434B2/en</span>
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="2002-02-15">2002-02-15</time>
#     <span itemprop="title">Assigned to PHILIP PLANT</span>
#     <span itemprop="type">reassignment</span>
#
#
#
#
#     <span itemprop="assigneeSearch">PHILIP PLANT</span>
#     <span itemprop="description" repeat>SECURITY INTEREST (SEE DOCUMENT FOR DETAILS).</span>
#     <span itemprop="description" repeat>Assignors: BC INTERNATIONAL CORPORATION, BCI LOUISIANA LLC</span>
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="2004-12-10">2004-12-10</time>
#     <span itemprop="title">Priority to US11/009,209</span>
#     <span itemprop="type">priority</span>
#
#
#
#     <span itemprop="documentId">patent/US20050158836A1/en</span>
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="2007-03-20">2007-03-20</time>
#     <span itemprop="title">Priority to US11/725,728</span>
#     <span itemprop="type">priority</span>
#
#
#
#     <span itemprop="documentId">patent/US20070172937A1/en</span>
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date" datetime="2008-08-31">2008-08-31</time>
#     <span itemprop="title">Anticipated expiration</span>
#     <span itemprop="type">legal-status</span>
#     <span itemprop="critical" content="true" bool>Critical</span>
#
#
#
#
#   </dd>
#   <dd itemprop="events" itemscope repeat>
#     <time itemprop="date">Status</time>
#     <span itemprop="title">Expired - Lifetime</span>
#     <span itemprop="type">legal-status</span>
#     <span itemprop="critical" content="true" bool>Critical</span>
#     <span itemprop="current" content="true" bool>Current</span>
#
#
#
#   </dd>
#
#   <h2>Links</h2>
#   <ul>
#
#         <li itemprop="links" itemscope repeat>
#           <meta itemprop="id" content="usptoLink">
#           <a href="https://patft.uspto.gov/netacgi/nph-Parser?Sect1=PTO1&Sect2=HITOFF&p=1&u=/netahtml/PTO/srchnum.html&r=1&f=G&l=50&d=PALL&s1=5000000.PN." itemprop="url" target="_blank"><span itemprop="text">USPTO</span></a>
#         </li>
#         <li itemprop="links" itemscope repeat>
#           <meta itemprop="id" content="usptoPatentCenterLink">
#           <a href="https://patentcenter.uspto.gov/applications/07352062" itemprop="url" target="_blank"><span itemprop="text">USPTO PatentCenter</span></a>
#         </li>
#         <li itemprop="links" itemscope repeat>
#           <meta itemprop="id" content="usptoAssignmentLink">
#           <a href="https://assignment.uspto.gov/patent/index.html#/patent/search/resultFilter?searchInput=5000000" itemprop="url" target="_blank"><span itemprop="text">USPTO Assignment</span></a>
#         </li>
#
#     <li itemprop="links" itemscope repeat>
#         <meta itemprop="id" content="espacenetLink">
#         <a href="https://worldwide.espacenet.com/publicationDetails/biblio?CC=US&amp;NR=5000000A&amp;KC=A&amp;FT=D" itemprop="url" target="_blank"><span itemprop="text">Espacenet</span></a>
#       </li>
#
#
#
#
#     <li itemprop="links" itemscope repeat>
#       <meta itemprop="id" content="globalDossierLink">
#       <a href="https://globaldossier.uspto.gov/result/application/US/07352062/1" itemprop="url" target="_blank"><span itemprop="text">Global Dossier</span></a>
#     </li>
#
#
#
#
#
#
#
#       <li itemprop="links" itemscope repeat>
#         <meta itemprop="id" content="stackexchangeLink">
#         <a href="https://patents.stackexchange.com/questions/tagged/US5000000" itemprop="url"><span itemprop="text">Discuss</span></a>
#       </li>
#
#   </ul>
#
#   <ul itemprop="concept" itemscope>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">108010021809</span>
#       <span itemprop="name">Alcohol dehydrogenase</span>
#       <span itemprop="domain">Proteins</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>title</span>
#       <span itemprop="sections" repeat>claims</span>
#       <span itemprop="sections" repeat>abstract</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">50</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">LFQSCWFLJHTTHZ-UHFFFAOYSA-N</span>
#       <span itemprop="name">Ethanol</span>
#       <span itemprop="domain">Chemical compound</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles">CCO</span>
#       <span itemprop="inchi_key">LFQSCWFLJHTTHZ-UHFFFAOYSA-N</span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>title</span>
#       <span itemprop="sections" repeat>claims</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">405</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">241000588724</span>
#       <span itemprop="name">Escherichia coli</span>
#       <span itemprop="domain">Species</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>title</span>
#       <span itemprop="sections" repeat>claims</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">69</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">238000004519</span>
#       <span itemprop="name">manufacturing process</span>
#       <span itemprop="domain">Methods</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>title</span>
#       <span itemprop="sections" repeat>claims</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">57</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">241000588901</span>
#       <span itemprop="name">Zymomonas</span>
#       <span itemprop="domain">Species</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>title</span>
#       <span itemprop="count">1</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">108090000623</span>
#       <span itemprop="name">proteins and genes</span>
#       <span itemprop="domain">Proteins</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>claims</span>
#       <span itemprop="sections" repeat>abstract</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">72</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">241000588902</span>
#       <span itemprop="name">Zymomonas mobilis</span>
#       <span itemprop="domain">Species</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>claims</span>
#       <span itemprop="sections" repeat>abstract</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">69</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">108010011939</span>
#       <span itemprop="name">Pyruvate Decarboxylase</span>
#       <span itemprop="domain">Proteins</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>claims</span>
#       <span itemprop="sections" repeat>abstract</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">54</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">239000013612</span>
#       <span itemprop="name">plasmid</span>
#       <span itemprop="domain">Substances</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>claims</span>
#       <span itemprop="sections" repeat>abstract</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">50</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">102000007698</span>
#       <span itemprop="name">Alcohol dehydrogenase</span>
#       <span itemprop="domain">Human genes</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>claims</span>
#       <span itemprop="sections" repeat>abstract</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">44</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">238000000034</span>
#       <span itemprop="name">method</span>
#       <span itemprop="domain">Methods</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>claims</span>
#       <span itemprop="sections" repeat>abstract</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">13</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">230000004151</span>
#       <span itemprop="name">fermentation</span>
#       <span itemprop="domain">Effects</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>claims</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">45</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">238000000855</span>
#       <span itemprop="name">fermentation</span>
#       <span itemprop="domain">Methods</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>claims</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">45</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">230000009466</span>
#       <span itemprop="name">transformation</span>
#       <span itemprop="domain">Effects</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>claims</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">3</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">230000001131</span>
#       <span itemprop="name">transforming effect</span>
#       <span itemprop="domain">Effects</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>claims</span>
#       <span itemprop="count">1</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">230000012010</span>
#       <span itemprop="name">growth</span>
#       <span itemprop="domain">Effects</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>abstract</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">65</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">210000004027</span>
#       <span itemprop="name">cell</span>
#       <span itemprop="domain">Anatomy</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>abstract</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">54</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">230000000694</span>
#       <span itemprop="name">effects</span>
#       <span itemprop="domain">Effects</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>abstract</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">42</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">244000005700</span>
#       <span itemprop="name">microbiome</span>
#       <span itemprop="domain">Species</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>abstract</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">11</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">238000009825</span>
#       <span itemprop="name">accumulation</span>
#       <span itemprop="domain">Methods</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>abstract</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">3</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">210000003527</span>
#       <span itemprop="name">eukaryotic cell</span>
#       <span itemprop="domain">Anatomy</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>abstract</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">3</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">239000001963</span>
#       <span itemprop="name">growth medium</span>
#       <span itemprop="domain">Substances</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>abstract</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">3</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">230000002503</span>
#       <span itemprop="name">metabolic effect</span>
#       <span itemprop="domain">Effects</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>abstract</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">3</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">SRBFZHDQGSBBOR-IOVATXLUSA-N</span>
#       <span itemprop="name">D-xylopyranose</span>
#       <span itemprop="domain">Chemical compound</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles">O[C@@H]1COC(O)[C@H](O)[C@H]1O</span>
#       <span itemprop="inchi_key">SRBFZHDQGSBBOR-IOVATXLUSA-N</span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">74</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">WQZGKKKJIJFFOK-GASJEMHNSA-N</span>
#       <span itemprop="name">Glucose</span>
#       <span itemprop="domain">Natural products</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles">OC[C@H]1OC(O)[C@H](O)[C@@H](O)[C@@H]1O</span>
#       <span itemprop="inchi_key">WQZGKKKJIJFFOK-GASJEMHNSA-N</span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">59</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">239000008103</span>
#       <span itemprop="name">glucose</span>
#       <span itemprop="domain">Substances</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">59</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">PYMYPHUHKUWMLA-UHFFFAOYSA-N</span>
#       <span itemprop="name">arabinose</span>
#       <span itemprop="domain">Natural products</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles">OCC(O)C(O)C(O)C=O</span>
#       <span itemprop="inchi_key">PYMYPHUHKUWMLA-UHFFFAOYSA-N</span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">42</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">SRBFZHDQGSBBOR-UHFFFAOYSA-N</span>
#       <span itemprop="name">beta-D-Pyranose-Lyxose</span>
#       <span itemprop="domain">Natural products</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles">OC1COC(O)C(O)C1O</span>
#       <span itemprop="inchi_key">SRBFZHDQGSBBOR-UHFFFAOYSA-N</span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">42</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">239000000047</span>
#       <span itemprop="name">product</span>
#       <span itemprop="domain">Substances</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">42</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">102000004190</span>
#       <span itemprop="name">Enzymes</span>
#       <span itemprop="domain">Human genes</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">41</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">108090000790</span>
#       <span itemprop="name">Enzymes</span>
#       <span itemprop="domain">Proteins</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">41</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">235000000346</span>
#       <span itemprop="name">sugar</span>
#       <span itemprop="domain">Nutrition</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">40</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">GUBGYTABKSRVRQ-QKKXKWKRSA-N</span>
#       <span itemprop="name">Lactose</span>
#       <span itemprop="domain">Natural products</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles">OC[C@H]1O[C@@H](O[C@H]2[C@H](O)[C@@H](O)C(O)O[C@@H]2CO)[C@H](O)[C@@H](O)[C@H]1O</span>
#       <span itemprop="inchi_key">GUBGYTABKSRVRQ-QKKXKWKRSA-N</span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">27</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">230000014509</span>
#       <span itemprop="name">gene expression</span>
#       <span itemprop="domain">Effects</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">27</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">239000008101</span>
#       <span itemprop="name">lactose</span>
#       <span itemprop="domain">Substances</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">27</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">150000008163</span>
#       <span itemprop="name">sugars</span>
#       <span itemprop="domain">Chemical class</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">21</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">102000004169</span>
#       <span itemprop="name">proteins and genes</span>
#       <span itemprop="domain">Human genes</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">18</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">229940076788</span>
#       <span itemprop="name">pyruvate</span>
#       <span itemprop="domain">Drugs</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">18</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">LCTONWCANYUPML-UHFFFAOYSA-M</span>
#       <span itemprop="name">Pyruvate</span>
#       <span itemprop="domain">Chemical compound</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles">CC(=O)C([O-])=O</span>
#       <span itemprop="inchi_key">LCTONWCANYUPML-UHFFFAOYSA-M</span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">17</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">239000002609</span>
#       <span itemprop="name">medium</span>
#       <span itemprop="domain">Substances</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">17</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">230000037361</span>
#       <span itemprop="name">pathway</span>
#       <span itemprop="domain">Effects</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
#       <span itemprop="smiles"></span>
#       <span itemprop="inchi_key"></span>
#       <span itemprop="similarity">0.000</span>
#       <span itemprop="sections" repeat>description</span>
#       <span itemprop="count">15</span>
#     </li>
#     <li itemprop="match" itemscope repeat>
#       <span itemprop="id">WQZGKKKJIJFFOK-VFUOTHLCSA-N</span>
#       <span itemprop="name">beta-D-glucose</span>
#       <span itemprop="domain">Chemical compound</span>
#       <span itemprop="svg_large"></span>
#       <span itemprop="svg_small"></span>
# ...
#
#
#           </td>
#           <td itemprop="title">Processes for ethanol production
#        </td>
#         </tr>
#         <tr itemprop="similarDocuments" itemscope repeat>
#           <td>
#
#             <meta itemprop="isScholar" content="true">
#               <meta itemprop="scholarID" content="7110705281564865387">
#               <a href="/scholar/7110705281564865387"><span itemprop="scholarAuthors">Lacis et al.</span></a>
#
#           </td>
#           <td>
#
#             <time itemprop="publicationDate" datetime="1991">1991</time>
#
#           </td>
#           <td itemprop="title">Thermoanaerobacter ethanolicus growth and product yield from elevated levels of xylose or glucose in continuous cultures</td>
#         </tr>
#         <tr itemprop="similarDocuments" itemscope repeat>
#           <td>
#             <meta itemprop="isPatent" content="true">
#               <a href="/patent/US6107093A/en">
#                 <span itemprop="publicationNumber">US6107093A</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
#
#
#           </td>
#           <td>
#             <time itemprop="publicationDate" datetime="2000-08-22">2000-08-22</time>
#
#
#           </td>
#           <td itemprop="title">Recombinant cells that highly express chromosomally-integrated heterologous genes
#        </td>
#         </tr>
#         <tr itemprop="similarDocuments" itemscope repeat>
#           <td>
#             <meta itemprop="isPatent" content="true">
#               <a href="/patent/US20070172937A1/en">
#                 <span itemprop="publicationNumber">US20070172937A1</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
#
#
#           </td>
#           <td>
#             <time itemprop="publicationDate" datetime="2007-07-26">2007-07-26</time>
#
#
#           </td>
#           <td itemprop="title">Recombinant cells that highly express chromosomally-integrated heterologous genes
#      </td>
#         </tr>
#         <tr itemprop="similarDocuments" itemscope repeat>
#           <td>
#             <meta itemprop="isPatent" content="true">
#               <a href="/patent/US6849434B2/en">
#                 <span itemprop="publicationNumber">US6849434B2</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
#
#
#           </td>
#           <td>
#             <time itemprop="publicationDate" datetime="2005-02-01">2005-02-01</time>
#
#
#           </td>
#           <td itemprop="title">Ethanol production in recombinant hosts
#        </td>
#         </tr>
#         <tr itemprop="similarDocuments" itemscope repeat>
#           <td>
#             <meta itemprop="isPatent" content="true">
#               <a href="/patent/EP0560885B1/en">
#                 <span itemprop="publicationNumber">EP0560885B1</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
#
#
#           </td>
#           <td>
#             <time itemprop="publicationDate" datetime="1999-03-17">1999-03-17</time>
#
#
#           </td>
#           <td itemprop="title">Recombinant cells that highly express chromosomally-integrated heterologous genes
#        </td>
#         </tr>
#         <tr itemprop="similarDocuments" itemscope repeat>
#           <td>
#
#             <meta itemprop="isScholar" content="true">
#               <meta itemprop="scholarID" content="6742557336631698048">
#               <a href="/scholar/6742557336631698048"><span itemprop="scholarAuthors">Feldmann et al.</span></a>
#
#           </td>
#           <td>
#
#             <time itemprop="publicationDate" datetime="1989">1989</time>
#
#           </td>
#           <td itemprop="title">Ethanol production from xylose with a pyruvate-formate-lyase mutant of Klebsiella planticola carrying a pyruvate-decarboxylase gene from Zymomonas mobilis</td>
#         </tr>
#         <tr itemprop="similarDocuments" itemscope repeat>
#           <td>
#             <meta itemprop="isPatent" content="true">
#               <a href="/patent/US20050158836A1/en">
#                 <span itemprop="publicationNumber">US20050158836A1</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
#
#
#           </td>
#           <td>
#             <time itemprop="publicationDate" datetime="2005-07-21">2005-07-21</time>
#
#
#           </td>
#           <td itemprop="title">Ethanol production in gram-positive microbes
#        </td>
#         </tr>
#         <tr itemprop="similarDocuments" itemscope repeat>
#           <td>
#
#             <meta itemprop="isScholar" content="true">
#               <meta itemprop="scholarID" content="3715453232192013229">
#               <a href="/scholar/3715453232192013229"><span itemprop="scholarAuthors">Lawford et al.</span></a>
#
#           </td>
#           <td>
#
#             <time itemprop="publicationDate" datetime="1997">1997</time>
#
#           </td>
#           <td itemprop="title">Fermentation of biomass-derived glucuronic acid by pet expressing recombinants of E. coli B</td>
#         </tr>
#         <tr itemprop="similarDocuments" itemscope repeat>
#           <td>
#             <meta itemprop="isPatent" content="true">
#               <a href="/patent/CN101775363A/en">
#                 <span itemprop="publicationNumber">CN101775363A</span>
#                 (<span itemprop="primaryLanguage">en</span>)
#               </a>
#
#
#           </td>
#           <td>
#             <time itemprop="publicationDate" datetime="2010-07-14">2010-07-14</time>
#
#
#           </td>
#           <td itemprop="title">Ethanol production
#        </td>
#         </tr>
#         <tr itemprop="similarDocuments" itemscope repeat>
#           <td>
#
#             <meta itemprop="isScholar" content="true">
#               <meta itemprop="scholarID" content="17672946581294838546">
#               <a href="/scholar/17672946581294838546"><span itemprop="scholarAuthors">Lawford et al.</span></a>
#
#           </td>
#           <td>
#
#             <time itemprop="publicationDate" datetime="1996">1996</time>
#
#           </td>
#           <td itemprop="title">The relationship between growth enhancement and pet expression in Escherichia coli</td>
#         </tr>
#         <tr itemprop="similarDocuments" itemscope repeat>
#           <td>
#
#             <meta itemprop="isScholar" content="true">
#               <meta itemprop="scholarID" content="18379077769580539914">
#               <a href="/scholar/18379077769580539914"><span itemprop="scholarAuthors">Ingram et al.</span></a>
#
#           </td>
#           <td>
#
#             <time itemprop="publicationDate" datetime="1991">1991</time>
#
#           </td>
#           <td itemprop="title">Ethanol production using engineered mutant E. coli</td>
#         </tr>
#       </tbody>
#     </table>
#   </section>
#
#   <section>
#     <h2>Legal Events</h2>
#     <table>
#       <thead>
#         <tr>
#           <th>Date</th>
#           <th>Code</th>
#           <th>Title</th>
#           <th>Description</th>
#         </tr>
#       </thead>
#       <tbody>
#         <tr itemprop="legalEvents" itemscope repeat>
#           <td><time itemprop="date" datetime="1989-05-15">1989-05-15</time></td>
#           <td itemprop="code">AS</td>
#           <td itemprop="title">Assignment</td>
#           <td>
#             <p itemprop="attributes" itemscope repeat>
#               <strong itemprop="label">Owner name</strong>:
#               <span itemprop="value">UNIVERSITY OF FLORIDA, THE, 207 TIGERT HALL, GAINE</span>
#             </p>
#             <p itemprop="attributes" itemscope repeat>
#               <strong itemprop="label">Free format text</strong>:
#               <span itemprop="value">ASSIGNMENT OF ASSIGNORS INTEREST.;ASSIGNORS:INGRAM, LONNIE O.;ALTERTHUM, FLAVIO;REEL/FRAME:005083/0452</span>
#             </p>
#             <p itemprop="attributes" itemscope repeat>
#               <strong itemprop="label">Effective date</strong>:
#               <span itemprop="value">19890512</span>
#             </p>
#           </td>
#         </tr>
#         <tr itemprop="legalEvents" itemscope repeat>
#           <td><time itemprop="date" datetime="1989-06-01">1989-06-01</time></td>
#           <td itemprop="code">AS</td>
#           <td itemprop="title">Assignment</td>
#           <td>
#             <p itemprop="attributes" itemscope repeat>
#               <strong itemprop="label">Owner name</strong>:
#               <span itemprop="value">UNIVERSITY OF FLORIDA, THE, FLORIDA</span>
#             </p>
#             <p itemprop="attributes" itemscope repeat>
#               <strong itemprop="label">Free format text</strong>:
#               <span itemprop="value">ASSIGNMENT OF ASSIGNORS INTEREST.;ASSIGNOR:CONWAY, TYRRELL;REEL/FRAME:005090/0705</span>
#             </p>
#             <p itemprop="attributes" itemscope repeat>
#               <strong itemprop="label">Effective date</strong>:
#               <span itemprop="value">19890522</span>
#             </p>
#           </td>
#         </tr>
#         <tr itemprop="legalEvents" itemscope repeat>
#           <td><time itemprop="date" datetime="1991-01-18">1991-01-18</time></td>
#           <td itemprop="code">STCF</td>
#           <td itemprop="title">Information on status: patent grant</td>
#           <td>
#             <p itemprop="attributes" itemscope repeat>
#               <strong itemprop="label">Free format text</strong>:
#               <span itemprop="value">PATENTED CASE</span>
#             </p>
#           </td>
#         </tr>
#         <tr itemprop="legalEvents" itemscope repeat>
#           <td><time itemprop="date" datetime="1993-12-09">1993-12-09</time></td>
#           <td itemprop="code">AS</td>
#           <td itemprop="title">Assignment</td>
#           <td>
#             <p itemprop="attributes" itemscope repeat>
#               <strong itemprop="label">Owner name</strong>:
#               <span itemprop="value">UNIVERSITY OF FLORIDA RESEARCH FOUNDATION, INCORPO</span>
#             </p>
#             <p itemprop="attributes" itemscope repeat>
#               <strong itemprop="label">Free format text</strong>:
#               <span itemprop="value">ASSIGNMENT OF ASSIGNORS INTEREST;ASSIGNOR:UNIVERSITY OF FLORIDA;REEL/FRAME:006796/0219</span>
#             </p>
#             <p itemprop="attributes" itemscope repeat>
#               <strong itemprop="label">Effective date</strong>:
#               <span itemprop="value">19900521</span>
#             </p>
#           </td>
#         </tr>
#         <tr itemprop="legalEvents" itemscope repeat>
#           <td><time itemprop="date" datetime="1993-12-09">1993-12-09</time></td>
#           <td itemprop="code">FEPP</td>
#           <td itemprop="title">Fee payment procedure</td>
#           <td>
#             <p itemprop="attributes" itemscope repeat>
#               <strong itemprop="label">Free format text</strong>:
#               <span itemprop="value">PAYOR NUMBER ASSIGNED (ORIGINAL EVENT CODE: ASPN); ENTITY STATUS OF PATENT OWNER: LARGE ENTITY</span>
#             </p>
#           </td>
#         </tr>
#         <tr itemprop="legalEvents" itemscope repeat>
#           <td><time itemprop="date" datetime="1994-09-12">1994-09-12</time></td>
#           <td itemprop="code">FPAY</td>
#           <td itemprop="title">Fee payment</td>
#           <td>
#             <p itemprop="attributes" itemscope repeat>
#               <strong itemprop="label">Year of fee payment</strong>:
#               <span itemprop="value">4</span>
#             </p>
#           </td>
#         </tr>
#         <tr itemprop="legalEvents" itemscope repeat>
#           <td><time itemprop="date" datetime="1998-09-14">1998-09-14</time></td>
#           <td itemprop="code">FPAY</td>
#           <td itemprop="title">Fee payment</td>
#           <td>
#             <p itemprop="attributes" itemscope repeat>
#               <strong itemprop="label">Year of fee payment</strong>:
#               <span itemprop="value">8</span>
#             </p>
#           </td>
#         </tr>
#         <tr itemprop="legalEvents" itemscope repeat>
#           <td><time itemprop="date" datetime="1998-12-01">1998-12-01</time></td>
#           <td itemprop="code">FEPP</td>
#           <td itemprop="title">Fee payment procedure</td>
#           <td>
#             <p itemprop="attributes" itemscope repeat>
#               <strong itemprop="label">Free format text</strong>:
#               <span itemprop="value">PAYER NUMBER DE-ASSIGNED (ORIGINAL EVENT CODE: RMPN); ENTITY STATUS OF PATENT OWNER: LARGE ENTITY</span>
#             </p>
#             <p itemprop="attributes" itemscope repeat>
#               <strong itemprop="label">Free format text</strong>:
#               <span itemprop="value">PAYOR NUMBER ASSIGNED (ORIGINAL EVENT CODE: ASPN); ENTITY STATUS OF PATENT OWNER: LARGE ENTITY</span>
#             </p>
#           </td>
#         </tr>
#         <tr itemprop="legalEvents" itemscope repeat>
#           <td><time itemprop="date" datetime="2002-02-15">2002-02-15</time></td>
#           <td itemprop="code">AS</td>
#           <td itemprop="title">Assignment</td>
#           <td>
#             <p itemprop="attributes" itemscope repeat>
#               <strong itemprop="label">Owner name</strong>:
#               <span itemprop="value">PHILIP PLANT, TEXAS</span>
#             </p>
#             <p itemprop="attributes" itemscope repeat>
#               <strong itemprop="label">Free format text</strong>:
#               <span itemprop="value">SECURITY INTEREST;ASSIGNORS:BC INTERNATIONAL CORPORATION;BCI LOUISIANA LLC;REEL/FRAME:012653/0509</span>
#             </p>
#             <p itemprop="attributes" itemscope repeat>
#               <strong itemprop="label">Effective date</strong>:
#               <span itemprop="value">20020214</span>
#             </p>
#           </td>
#         </tr>
#         <tr itemprop="legalEvents" itemscope repeat>
#           <td><time itemprop="date" datetime="2002-08-29">2002-08-29</time></td>
#           <td itemprop="code">FPAY</td>
#           <td itemprop="title">Fee payment</td>
#           <td>
#             <p itemprop="attributes" itemscope repeat>
#               <strong itemprop="label">Year of fee payment</strong>:
#               <span itemprop="value">12</span>
#             </p>
#           </td>
#         </tr>
#       </tbody>
#     </table>
#   </section>
#
# </article>
#
#     </search-app>
#
#     <script></script>
#     <script type="text/javascript" src="//www.gstatic.com/feedback/api.js"></script>
#     <script type="text/javascript" src="//www.gstatic.com/feedback/js/help/prod/service/lazy.min.js"></script>
#     <script type="text/javascript">
#       if (window.help && window.help.service) {
#         helpApi = window.help.service.Lazy.create(0, {apiKey: 'AIzaSyDTEI_0tLX4varJ7bwK8aT-eOI5qr3BmyI', locale: 'en-US'});
#         window.requestedSurveys = new Set();
#         window.requestSurvey = function(triggerId) {
#           if (window.requestedSurveys.has(triggerId)) {
#             return;
#           }
#           window.requestedSurveys.add(triggerId);
#           helpApi.requestSurvey({
#             triggerId: triggerId,
#             enableTestingMode: false,
#             callback: (requestSurveyCallbackParam) => {
#               if (!requestSurveyCallbackParam.surveyData) {
#                 return;
#               }
#               helpApi.presentSurvey({
#                 productData: {
#                   productVersion: window.version,
#                   customData: {
#                     "experiments": "",
#                   },
#                 },
#                 surveyData: requestSurveyCallbackParam.surveyData,
#                 colorScheme: 1,
#                 customZIndex: 10000,
#               });
#             }
#           });
#         };
#
#         window.requestSurvey('YXTwAsvoW0kedxbuTdH0RArc9VhT');
#       }
#     </script>
#     <script src="/sw/null_loader.js"></script>
#   </body>
# </html>

# %%
url = "https://patents.google.com/patent/US5000000B/en?oq=US5000000"
html = urlopen(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 url = "https://patents.google.com/patent/US5000000B/en?oq=US5000000"
# ----> 2 html = urlopen(url)
#
# File ~\InstallAnaconda\envs\academia3_13\Lib\urllib\request.py:189, in urlopen(url, data, timeout, context)
#     187 else:
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File ~\InstallAnaconda\envs\academia3_13\Lib\urllib\request.py:495, in OpenerDirector.open(self, fullurl, data, timeout)
#     493 for processor in self.process_response.get(protocol, []):
#     494     meth = getattr(processor, meth_name)
# --> 495     response = meth(req, response)
#     497 return response
#
# File ~\InstallAnaconda\envs\academia3_13\Lib\urllib\request.py:604, in HTTPErrorProcessor.http_response(self, request, response)
#     601 # According to RFC 2616, "2xx" code indicates that the client's
#     602 # request was successfully received, understood, and accepted.
#     603 if not (200 <= code < 300):
# --> 604     response = self.parent.error(
#     605         'http', request, response, code, msg, hdrs)
#     607 return response
#
# File ~\InstallAnaconda\envs\academia3_13\Lib\urllib\request.py:533, in OpenerDirector.error(self, proto, *args)
#     531 if http_err:
#     532     args = (dict, 'default', 'http_error_default') + orig_args
# --> 533     return self._call_chain(*args)
#
# File ~\InstallAnaconda\envs\academia3_13\Lib\urllib\request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     464 for handler in handlers:
#     465     func = getattr(handler, meth_name)
# --> 466     result = func(*args)
#     467     if result is not None:
#     468         return result
#
# File ~\InstallAnaconda\envs\academia3_13\Lib\urllib\request.py:613, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     612 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 613     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found

# %%
from urllib.error import HTTPError
url = "https://patents.google.com/patent/US5000000B/en?oq=US5000000"
try:
    html = urlopen(url)
    print("sucesso")
except HTTPError as e:
    print(f"Erro HTTP {e}")
except URLError as e:
    print(f"Erro URL {e}")
except Exception as e:
    print(f"Erro Exception {e}")
# Out:
# Erro HTTP HTTP Error 404: Not Found

# %%
from urllib.error import HTTPError
url = "https://patents.google.com/patent/US5000000B/en?oq=US5000000"
try:
    html = urlopen(url)
    print("sucesso")
except Exception as e:
    print(f"Erro Exception {e}")
# Out:
# Erro Exception HTTP Error 404: Not Found

# %%
i = input("entre um valor")
y = int(i)
print(y)
# Out:
# entre um valor u
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 i = input("entre um valor")
# ----> 2 y = int(i)
#       3 print(y)
#
# ValueError: invalid literal for int() with base 10: 'u'

# %%
i = input("entre um valor")
try:
    y = int(i)
    print(y)
except ValueError as e:
    print(e)
# Out:
# entre um valor t
# invalid literal for int() with base 10: 't'

# %%
i = input("entre um valor")
try:
    y = int(i)
    print(y)
except Exception as e:
    print(e)
# Out:
# entre um valor p
# invalid literal for int() with base 10: 'p'
